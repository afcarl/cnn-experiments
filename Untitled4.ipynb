# %%
# %matplotlib inline

# %%
import urllib
urllib.request.urlretrieve("https://s3.amazonaws.com/assets.datacamp.com/production/course_6052/datasets/bricks.png", 
                           "bricks.png")
# Out:
# ('bricks.png', <http.client.HTTPMessage at 0x10f1f9c18>)

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
bricks = plt.imread('bricks.png')

# %%
plt.imshow(bricks)

# %%
bricks.shape
# Out:
# (159, 240, 4)

# %%
plt.imshow(bricks[:,:,0])
